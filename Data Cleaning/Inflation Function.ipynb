# %%
import pandas as pd

# %%
#This code assums that the name column is the first column
#read csv into dataframes
#one dataframe is worldwide box office data, the other is just the name and year movie was released
df_rev = pd.read_csv('boxofficemojo.csv')
df_years = pd.read_csv('Prophethuge (1).csv', index_col = 0, usecols = ['Name','Date Released'])

#remove rows with unknown values
df_years = df_years[df_years.ne('unknown').all(axis=1)]

#convert date released column to datetime
df_years['year'] = pd.to_datetime(df_years['Date Released']).dt.year

#calculate year differential
for i in df_years:
    df_years['year_diff'] = 2023 - df_years['year']
    

#drop year column as unnecessary, only used to calculate year differential
df_years = df_years.drop(columns='year')

#remove year differential column
df_years = df_years.drop(columns='Date Released')
    
#print dataframe
print(df_years)
# Out:
#                                year_diff
# Name
# Babylon                                1
# A Man Called Otto                      0
# Shotgun Wedding                        0
# I Wanna Dance with Somebody            1
# Narvik: Hitler's First Defeat          0
# ...                                  ...
# Love Liza                             20
# Real Women Have Curves                21
# The Dancer Upstairs                   21
# Tadpole                               21
# Biggie and Tupac                      21
#
# [8177 rows x 1 columns]

# %%
# Identify columns that are integers
# Remove the second and third columns
df_rev = df_rev.drop(columns=['ID','Distributor'])

# Display the resulting DataFrame
print(df_rev)
# Out:
#                               Name Worldwide Gross Revenue (sus)  \
# 0         Avatar: The Way of Water                $2,320,250,281
# 1     Puss in Boots: The Last Wish                  $481,080,374
# 2                          Babylon                   $63,351,455
# 3                A Man Called Otto                  $113,190,218
# 4                            M3GAN                  $179,973,454
# ...                            ...                           ...
# 2586              Enter the Dragon                      $114,252
# 2587             American Graffiti                  $115,000,889
# 2588              Live and Let Die                   $35,382,710
# 2589                   Deliverance                        $4,534
# 2590                 The Godfather                  $250,341,816
#
#      Domestic Opening Domestic Gross China Opening   China Gross   UK Opening  \
# 0        $134,100,226   $684,075,767   $56,798,896  $245,996,272  $13,590,332
# 1         $12,429,515   $185,535,345      $350,222    $6,865,487   $5,952,350
# 2          $3,603,368    $15,351,455       unknown       unknown   $1,640,861
# 3             $56,257    $64,267,657       unknown       unknown   $1,316,253
# 4         $30,429,860    $95,043,350    $1,623,380    $3,251,874   $2,881,336
# ...               ...            ...           ...           ...          ...
# 2586          unknown        $25,259       unknown       unknown      unknown
# 2587          unknown   $115,000,000       unknown       unknown      unknown
# 2588          unknown    $35,377,836       unknown       unknown      unknown
# 2589          unknown        unknown       unknown       unknown      unknown
# 2590          unknown   $136,381,073       unknown       unknown      unknown
#
#          UK Gross France Opening  France Gross  ... Japan Opening  \
# 0     $93,320,842    $13,922,403  $157,099,579  ...    $4,727,204
# 1     $30,918,836     $3,387,317   $23,460,953  ...      $433,343
# 2      $4,838,305     $3,348,177   $13,001,491  ...       unknown
# 3      $5,762,972       $415,041      $703,583  ...      $327,369
# 4      $8,865,482     $1,396,239    $3,774,829  ...    $1,045,845
# ...           ...            ...           ...  ...           ...
# 2586      $46,207        unknown       unknown  ...       unknown
# 2587      $46,207        unknown       unknown  ...       unknown
# 2588       $4,874        unknown       unknown  ...       unknown
# 2589      unknown        unknown       unknown  ...       unknown
# 2590     $358,278        unknown       unknown  ...       unknown
#
#       Japan Gross South Korea Opening South Korea Gross Australia Opening  \
# 0     $32,525,343         $19,266,473      $108,045,923        $9,855,736
# 1      $1,834,292          $1,932,887        $6,376,812          $112,910
# 2      $2,268,792            $536,603        $1,584,325           unknown
# 3        $327,369             $90,008          $249,929          $326,239
# 4      $4,179,863            $690,608        $1,884,356        $1,341,599
# ...           ...                 ...               ...               ...
# 2586      unknown             unknown           unknown           unknown
# 2587      unknown             unknown           unknown           unknown
# 2588      unknown             unknown           unknown           unknown
# 2589      unknown             unknown           unknown           unknown
# 2590      unknown             unknown           unknown           unknown
#
#      Australia Gross Russia/CIS Opening Russia/CIS Gross India Opening  \
# 0        $63,840,735            unknown          unknown   $19,153,502
# 1        $15,131,903            unknown         $237,493      $211,656
# 2         $2,807,787            unknown          unknown       unknown
# 3         $5,186,036            unknown          unknown       unknown
# 4         $4,577,272            unknown           $6,123       $87,765
# ...              ...                ...              ...           ...
# 2586         unknown            unknown          unknown       unknown
# 2587         unknown            unknown          unknown       unknown
# 2588         unknown            unknown          unknown       unknown
# 2589         unknown            unknown          unknown       unknown
# 2590         unknown            unknown          unknown       unknown
#
#       India Gross
# 0     $59,554,397
# 1        $458,969
# 2         unknown
# 3         unknown
# 4        $219,017
# ...           ...
# 2586      unknown
# 2587      unknown
# 2588      unknown
# 2589      unknown
# 2590      unknown
#
# [2591 rows x 26 columns]

# %%
#format all values in all cells
df_rev = df_rev.applymap(lambda x: str(x).replace('$', ''))
df_rev = df_rev.applymap(lambda x: str(x).replace('unknown', '0'))
df_rev = df_rev.applymap(lambda x: str(x).replace(',', ''))

#set the index to the movie name
df_rev.set_index('Name', inplace = True)

#convert entire dataframe to integer to do calculations
df_rev = df_rev.astype('Int64')

#view resulting dataframe
print(df_rev)
# Out:
#                               Worldwide Gross Revenue (sus)  Domestic Opening  \
# Name
# Avatar: The Way of Water                         2320250281         134100226
# Puss in Boots: The Last Wish                      481080374          12429515
# Babylon                                            63351455           3603368
# A Man Called Otto                                 113190218             56257
# M3GAN                                             179973454          30429860
# ...                                                     ...               ...
# Enter the Dragon                                     114252                 0
# American Graffiti                                 115000889                 0
# Live and Let Die                                   35382710                 0
# Deliverance                                            4534                 0
# The Godfather                                     250341816                 0
#
#                               Domestic Gross  China Opening  China Gross  \
# Name
# Avatar: The Way of Water           684075767       56798896    245996272
# Puss in Boots: The Last Wish       185535345         350222      6865487
# Babylon                             15351455              0            0
# A Man Called Otto                   64267657              0            0
# M3GAN                               95043350        1623380      3251874
# ...                                      ...            ...          ...
# Enter the Dragon                       25259              0            0
# American Graffiti                  115000000              0            0
# Live and Let Die                    35377836              0            0
# Deliverance                                0              0            0
# The Godfather                      136381073              0            0
#
#                               UK Opening  UK Gross  France Opening  \
# Name
# Avatar: The Way of Water        13590332  93320842        13922403
# Puss in Boots: The Last Wish     5952350  30918836         3387317
# Babylon                          1640861   4838305         3348177
# A Man Called Otto                1316253   5762972          415041
# M3GAN                            2881336   8865482         1396239
# ...                                  ...       ...             ...
# Enter the Dragon                       0     46207               0
# American Graffiti                      0     46207               0
# Live and Let Die                       0      4874               0
# Deliverance                            0         0               0
# The Godfather                          0    358278               0
#
#                               France Gross  Germany Opening  ...  \
# Name                                                         ...
# Avatar: The Way of Water         157099579         16837927  ...
# Puss in Boots: The Last Wish      23460953          1105424  ...
# Babylon                           13001491                0  ...
# A Man Called Otto                   703583           740776  ...
# M3GAN                              3774829          1493354  ...
# ...                                    ...              ...  ...
# Enter the Dragon                         0                0  ...
# American Graffiti                        0                0  ...
# Live and Let Die                         0                0  ...
# Deliverance                              0                0  ...
# The Godfather                            0                0  ...
#
#                               Japan Opening  Japan Gross  South Korea Opening  \
# Name
# Avatar: The Way of Water            4727204     32525343             19266473
# Puss in Boots: The Last Wish         433343      1834292              1932887
# Babylon                                   0      2268792               536603
# A Man Called Otto                    327369       327369                90008
# M3GAN                               1045845      4179863               690608
# ...                                     ...          ...                  ...
# Enter the Dragon                          0            0                    0
# American Graffiti                         0            0                    0
# Live and Let Die                          0            0                    0
# Deliverance                               0            0                    0
# The Godfather                             0            0                    0
#
#                               South Korea Gross  Australia Opening  \
# Name
# Avatar: The Way of Water              108045923            9855736
# Puss in Boots: The Last Wish            6376812             112910
# Babylon                                 1584325                  0
# A Man Called Otto                        249929             326239
# M3GAN                                   1884356            1341599
# ...                                         ...                ...
# Enter the Dragon                              0                  0
# American Graffiti                             0                  0
# Live and Let Die                              0                  0
# Deliverance                                   0                  0
# The Godfather                                 0                  0
#
#                               Australia Gross  Russia/CIS Opening  \
# Name
# Avatar: The Way of Water             63840735                   0
# Puss in Boots: The Last Wish         15131903                   0
# Babylon                               2807787                   0
# A Man Called Otto                     5186036                   0
# M3GAN                                 4577272                   0
# ...                                       ...                 ...
# Enter the Dragon                            0                   0
# American Graffiti                           0                   0
# Live and Let Die                            0                   0
# Deliverance                                 0                   0
# The Godfather                               0                   0
#
#                               Russia/CIS Gross  India Opening  India Gross
# Name
# Avatar: The Way of Water                     0       19153502     59554397
# Puss in Boots: The Last Wish            237493         211656       458969
# Babylon                                      0              0            0
# A Man Called Otto                            0              0            0
# M3GAN                                     6123          87765       219017
# ...                                        ...            ...          ...
# Enter the Dragon                             0              0            0
# American Graffiti                            0              0            0
# Live and Let Die                             0              0            0
# Deliverance                                  0              0            0
# The Godfather                                0              0            0
#
# [2591 rows x 25 columns]

# %%
#merge dataframes on
merged_df = pd.merge(df_rev, df_years, left_index=True, right_index=True)

#define inflation rate
inflation = 0.03       
                           
#multiply all columns in dataframe by the inflation factor (per year)
for col in merged_df.columns:
    if col != 'year_diff':
        merged_df[col] = merged_df[col] * (1 + inflation) ** merged_df['year_diff']
        
#remove year differential column
merged_df = merged_df.drop(columns='year_diff')

#reset index
merged_df.reset_index(inplace=True)

#round all values to 2 decimals
merged_df = merged_df.round(2)

# %%
#export dataframe to csv
merged_df.to_csv('inflation_worldwide.csv', index=False)

#view dataframe
merged_df.head()
# Out:
#                    Name  Worldwide Gross Revenue (sus)  Domestic Opening  \
# 0  (500) Days of Summer                    91966126.86       22789221.33
# 1   10 Cloverfield Lane                   135553005.37       30411628.53
# 2             12 Strong                    78087762.63       18333948.47
# 3      12 Years a Slave                   252297725.11         179947.72
# 4             127 Hours                    86599001.08          377614.2
#
#    Domestic Gross  China Opening  China Gross  UK Opening     UK Gross  \
# 0     48994859.49            0.0          0.0         0.0  11490927.84
# 1     88652995.38            0.0          0.0   2851802.0   8740889.43
# 2     53117605.37            0.0          0.0   660057.04   1439076.46
# 3     76162419.64            0.0          0.0         0.0  44364223.84
# 4     26141653.79            0.0          0.0  4808419.94  17841810.63
#
#    France Opening  France Gross  ...  Japan Opening  Japan Gross  \
# 0             0.0    5573613.31  ...            0.0   4518229.54
# 1             0.0    3306972.17  ...            0.0          0.0
# 2       436164.12      682984.0  ...      933498.49   2270534.49
# 3             0.0     155160.52  ...            0.0          0.0
# 4      2131318.62    4127663.31  ...       668623.4     668623.4
#
#    South Korea Opening  South Korea Gross  Australia Opening  Australia Gross  \
# 0                  0.0         2294931.38                0.0       9948886.48
# 1           1646344.82         3106329.32         1352997.77       3755341.14
# 2            1156520.8         1992605.49          834294.77       1923770.11
# 3                  0.0          186911.89                0.0              0.0
# 4            816675.84         1701545.82          1712249.0       5118987.73
#
#    Russia/CIS Opening  Russia/CIS Gross  India Opening  India Gross
# 0                 0.0        6518422.23            0.0    446032.46
# 1           949094.89        1611151.98            0.0          0.0
# 2           111805.03         172537.08       128432.5    216029.56
# 3                 0.0               0.0            0.0          0.0
# 4           549807.62        1291826.33      758690.14   1392798.72
#
# [5 rows x 26 columns]

# %%
#do the same for the domestic data

# %%
#inflation for the main dataframe
df_g = pd.read_csv('Prophethuge (1).csv', index_col = 0, usecols = ['Name','Estimated Budget','Gross Revenue US&Canada USD', 'Opening Weekend Revenue US&Canada USD', 'Gross Revenue Worldwide USD'])
df_g = df_g.applymap(lambda x: str(x).replace('unknown', '0'))

#convert each column to integer then fill nan values with 0
df_g = df_g.apply(pd.to_numeric, errors='coerce').fillna(0)

#combine with previously made dataframe
df_m = pd.merge(df_g, df_years, left_index=True, right_index=True)

#define constants
current_year = 2023
inflation = 0.03

#multiply each value by inflation factor    
for col in df_m.columns:
    if col != 'year_diff':
        df_m[col] = df_m[col] * (1 + inflation) ** df_m['year_diff']
        
#remove year differential column
df_m = df_m.drop(columns='year_diff')

#round all values to 2 decimals
df_m = df_m.round(2)   

#reset index
df_m.reset_index(inplace=True)

#export to csv
df_m.to_csv('inflation_domestic.csv', index=False)

# %%
#print df
df_m
# Out:
#                             Name  Estimated Budget  \
# 0                            '71      0.000000e+00
# 1                            '83      0.000000e+00
# 2           (500) Days of Summer      1.134442e+07
# 3                           0.45      8.264238e+06
# 4                              1      4.031749e+06
# ...                          ...               ...
# 8486                        iBoy      2.985131e+06
# 8487                         xXx      1.302206e+08
# 8488  xXx: Return of Xander Cage      1.014944e+08
# 8489     xXx: State of the Union      1.923749e+08
# 8490                    Æon Flux      1.055508e+08
#
#       Gross Revenue US&Canada USD  Opening Weekend Revenue US&Canada USD  \
# 0                    1.658167e+06                               72755.46
# 1                    4.302650e+06                             1795652.82
# 2                    4.899486e+07                             1262257.64
# 3                    0.000000e+00                                   0.00
# 4                    1.059812e+04                               10598.12
# ...                           ...                                    ...
# 8486                 0.000000e+00                                   0.00
# 8487                 2.643653e+08                            82794461.82
# 8488                 5.361105e+07                            24036442.28
# 8489                 4.575107e+07                            21641792.14
# 8490                 4.404933e+07                            21554695.66
#
#       Gross Revenue Worldwide USD
# 0                    3.995448e+06
# 1                    7.798741e+06
# 2                    9.196613e+07
# 3                    2.831973e+05
# 4                    2.251572e+06
# ...                           ...
# 8486                 0.000000e+00
# 8487                 5.161357e+08
# 8488                 4.132833e+08
# 8489                 1.215718e+08
# 8490                 9.077658e+07
#
# [8491 rows x 5 columns]
