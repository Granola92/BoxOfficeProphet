# %%
pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.15.2-py3-none-any.whl (10.2 MB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /opt/conda/lib/python3.10/site-packages (from selenium) (1.26.13)
# Collecting trio~=0.17 (from selenium)
#   Using cached trio-0.23.1-py3-none-any.whl (448 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Using cached trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /opt/conda/lib/python3.10/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=20.1.0 in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium) (23.1.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /opt/conda/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sortedcontainers, outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 sortedcontainers-2.4.0 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
import requests
from bs4 import BeautifulSoup
import lxml
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import json
import numpy as np

# %%
#Read Andrew's IMDB data
df = pd.read_csv('Prophet1.csv', index_col = 0)
df['Name'] = df_movie.index
df_movie = pd.read_csv('Prophet1.csv', index_col = 0)
df_movie['Name'] = df_movie.index
df_movie.head()
# Out:
#                               IMDB Ratings  IMDB Score Content Rating  \
# Name
# Avatar: The Way of Water            469417         7.6             PG
# Puss in Boots: The Last Wish        161291         7.8             PG
# Babylon                             153248         7.1            18A
# A Man Called Otto                   141943         7.5              G
# M3GAN                               132495         6.4            14A
#
#                              Date Released  year  month  day of the week  \
# Name
# Avatar: The Way of Water        2022-12-16  2022     12                4
# Puss in Boots: The Last Wish    2022-12-21  2022     12                2
# Babylon                         2022-12-23  2022     12                4
# A Man Called Otto               2023-01-13  2023      1                4
# M3GAN                           2023-01-06  2023      1                4
#
#                                                           Genres    Genre A  \
# Name
# Avatar: The Way of Water        ['Action' 'Adventure' 'Fantasy']     Action
# Puss in Boots: The Last Wish  ['Animation' 'Adventure' 'Comedy']  Animation
# Babylon                             ['Comedy' 'Drama' 'History']     Comedy
# A Man Called Otto                             ['Comedy' 'Drama']     Comedy
# M3GAN                             ['Horror' 'Sci-Fi' 'Thriller']     Horror
#
#                                 Genre B  ...       Writer 3 Runtime  \
# Name                                     ...
# Avatar: The Way of Water      Adventure  ...  Amanda Silver     192
# Puss in Boots: The Last Wish  Adventure  ...    Tom Wheeler     102
# Babylon                           Drama  ...           none     189
# A Man Called Otto                 Drama  ...    David Magee     126
# M3GAN                            Sci-Fi  ...           none     102
#
#                              Nominations Awards Estimated Budget  \
# Name
# Avatar: The Way of Water             135     65        350000000
# Puss in Boots: The Last Wish          56      5         90000000
# Babylon                              146     43        110000000
# A Man Called Otto                      8      0         50000000
# M3GAN                                  2      1         12000000
#
#                              Budget Currency Gross Revenue US&Canada USD  \
# Name
# Avatar: The Way of Water                   $                   684075767
# Puss in Boots: The Last Wish               $                   185535345
# Babylon                                    $                    15351455
# A Man Called Otto                          $                    64267657
# M3GAN                                      $                    95043350
#
#                              Opening Weekend Revenue US&Canada USD  \
# Name
# Avatar: The Way of Water                                 134100226
# Puss in Boots: The Last Wish                              12429515
# Babylon                                                    3603368
# A Man Called Otto                                            56257
# M3GAN                                                     30429860
#
#                              Gross Revenue Worldwide USD  \
# Name
# Avatar: The Way of Water                      2320250281
# Puss in Boots: The Last Wish                   481080374
# Babylon                                         63351455
# A Man Called Otto                              113190218
# M3GAN                                          179973454
#
#                                                       Name
# Name
# Avatar: The Way of Water          Avatar: The Way of Water
# Puss in Boots: The Last Wish  Puss in Boots: The Last Wish
# Babylon                                            Babylon
# A Man Called Otto                        A Man Called Otto
# M3GAN                                                M3GAN
#
# [5 rows x 36 columns]

# %%
for i, idx in enumerate(df_movie.index):
    name = str(df_movie.loc[idx]['Name'])  # Convert to string if not already a string
    pattern = re.compile(r'[^A-Za-z0-9 ]+', re.UNICODE)
    name = re.sub(pattern, '', unidecode(name)).replace(' ', '_').lower()
    typ = 'm'
    year = df_movie.loc[idx]['year']
    
    # Construct URLs
    URL = f'https://www.rottentomatoes.com/{typ}/{name}/'
    URL2 = f'https://www.rottentomatoes.com/{typ}/{name}_{year}/'
    
    print(f"Processing: {URL}")
    
    # Fetch content from URL
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, 'html.parser')
    section = soup.find('script', {'id': 'scoreDetails'})

    #Append year for RT movies with duplicate names
    print(f"Processing: {URL2}")
    page2 = requests.get(URL2)
    soup2 = BeautifulSoup(page2.content, 'html.parser')
    section2 = soup2.find('script', {'id': 'scoreDetails'})
    
    if section is None or (section2 is not None and len(section2.string) > len(section.string)):
        selected_section = section2
    else:
        selected_section = section
    
    if selected_section is None: # Error handling for titles that cannot be found
        print(f'Could not scrape data for this movie: {df_movie.loc[idx]["Name"]}')
        print(f'Progress: {round((i+1)/len(df_movie) * 100, 2)}%')
    
    else:

        script_content = selected_section.string

        if script_content:
            data = json.loads(script_content)

            audience_score = data['modal']['audienceScoreAll'].get('averageRating', 'N/A')
            audience_count = data['modal']['audienceScoreAll'].get('ratingCount', 'N/A')
            tomato_score = data['modal']['tomatometerScoreAll'].get('averageRating', 'N/A')
            tomato_count = data['modal']['tomatometerScoreAll'].get('ratingCount', 'N/A')

            df_movie.loc[idx, 'RT_audience_score'] = audience_score
            df_movie.loc[idx, 'RT_tomatometer_score'] = tomato_score
            df_movie.loc[idx, 'RT_audience_#reviews'] = audience_count
            df_movie.loc[idx, 'RT_tomatometer_#reviews'] = tomato_count

            print(df_movie.loc[idx, ['RT_audience_score', 'RT_tomatometer_score', 'RT_audience_#reviews','RT_tomatometer_#reviews']])
            print(f'Progress: {round((i+1)/len(df_movie) * 100, 2)}%')
        else:
            print('Script content is empty')

df_movie.to_csv('movie_data_with_rt2.csv', index=False)  # Save the updated DataFrame to a CSV file
# Out:
# Processing: https://www.rottentomatoes.com/m/avatar_the_way_of_water/
# Processing: https://www.rottentomatoes.com/m/avatar_the_way_of_water_2022/
# RT_audience_score              4.3
# RT_tomatometer_score          7.10
# RT_audience_#reviews       48195.0
# RT_tomatometer_#reviews      448.0
# Name: Avatar: The Way of Water, dtype: object
# Progress: 0.04%
# Processing: https://www.rottentomatoes.com/m/puss_in_boots_the_last_wish/
# Processing: https://www.rottentomatoes.com/m/puss_in_boots_the_last_wish_2022/
# RT_audience_score              4.7
# RT_tomatometer_score          7.60
# RT_audience_#reviews       16575.0
# RT_tomatometer_#reviews      192.0
# Name: Puss in Boots: The Last Wish, dtype: object
# Progress: 0.08%
# Processing: https://www.rottentomatoes.com/m/babylon/
# Processing: https://www.rottentomatoes.com/m/babylon_2022/
# RT_audience_score             3.7
# RT_tomatometer_score         6.40
# RT_audience_#reviews       6999.0
# RT_tomatometer_#reviews     358.0
# Name: Babylon, dtype: object
# Progress: 0.12%
# Processing: https://www.rottentomatoes.com/m/a_man_called_otto/
# Processing: https://www.rottentomatoes.com/m/a_man_called_otto_2023/
# RT_audience_score              4.5
# RT_tomatometer_score          6.10
# RT_audience_#reviews       10436.0
# RT_tomatometer_#reviews      207.0
# Name: A Man Called Otto, dtype: object
# Progress: 0.16%
# Processing: https://www.rottentomatoes.com/m/m3gan/
# Processing: https://www.rottentomatoes.com/m/m3gan_2023/
# RT_audience_score              3.8
# RT_tomatometer_score          7.20
# RT_audience_#reviews       11348.0
# RT_tomatometer_#reviews      315.0
# Name: M3GAN, dtype: object
# Progress: 0.2%
# Processing: https://www.rottentomatoes.com/m/the_pale_blue_eye/
# Processing: https://www.rottentomatoes.com/m/the_pale_blue_eye_2023/
# RT_audience_score             3.7
# RT_tomatometer_score         6.00
# RT_audience_#reviews       1898.0
# RT_tomatometer_#reviews     189.0
# Name: The Pale Blue Eye, dtype: object
# Progress: 0.24%
# Processing: https://www.rottentomatoes.com/m/black_panther_wakanda_forever/
# Processing: https://www.rottentomatoes.com/m/black_panther_wakanda_forever_2022/
# RT_audience_score              4.1
# RT_tomatometer_score          7.10
# RT_audience_#reviews       38989.0
# RT_tomatometer_#reviews      447.0
# Name: Black Panther: Wakanda Forever, dtype: object
# Progress: 0.28%
# Processing: https://www.rottentomatoes.com/m/violent_night/
# Processing: https://www.rottentomatoes.com/m/violent_night_2022/
# RT_audience_score             4.1
# RT_tomatometer_score         6.50
# RT_audience_#reviews       5672.0
# RT_tomatometer_#reviews     208.0
# Name: Violent Night, dtype: object
# Progress: 0.32%
# Processing: https://www.rottentomatoes.com/m/black_adam/
# Processing: https://www.rottentomatoes.com/m/black_adam_2022/
# RT_audience_score              4.3
# RT_tomatometer_score          5.10
# RT_audience_#reviews       45629.0
# RT_tomatometer_#reviews      304.0
# Name: Black Adam, dtype: object
# Progress: 0.36%
# Processing: https://www.rottentomatoes.com/m/pinocchio/
# Processing: https://www.rottentomatoes.com/m/pinocchio_2022/
# RT_audience_score               2
# RT_tomatometer_score         4.80
# RT_audience_#reviews       3206.0
# RT_tomatometer_#reviews     181.0
# Name: Pinocchio, dtype: object
# Progress: 0.4%
# Processing: https://www.rottentomatoes.com/m/talk_to_me/
# Processing: https://www.rottentomatoes.com/m/talk_to_me_2023/
# RT_audience_score               4
# RT_tomatometer_score         7.70
# RT_audience_#reviews       5257.0
# RT_tomatometer_#reviews     285.0
# Name: Talk to Me, dtype: object
# Progress: 0.44%
# Processing: https://www.rottentomatoes.com/m/enola_holmes_2/
# Processing: https://www.rottentomatoes.com/m/enola_holmes_2_2022/
# RT_audience_score               4
# RT_tomatometer_score         7.00
# RT_audience_#reviews       2409.0
# RT_tomatometer_#reviews     104.0
# Name: Enola Holmes 2, dtype: object
# Progress: 0.48%
# Processing: https://www.rottentomatoes.com/m/glass_onion_a_knives_out_mystery/
# Processing: https://www.rottentomatoes.com/m/glass_onion_a_knives_out_mystery_2022/
# RT_audience_score             3.8
# RT_tomatometer_score         7.90
# RT_audience_#reviews       8512.0
# RT_tomatometer_#reviews     423.0
# Name: Glass Onion: A Knives Out Mystery, dtype: object
# Progress: 0.52%
# Processing: https://www.rottentomatoes.com/m/the_menu/
# Processing: https://www.rottentomatoes.com/m/the_menu_2022/
# RT_audience_score             3.8
# RT_tomatometer_score         7.50
# RT_audience_#reviews       9369.0
# RT_tomatometer_#reviews     327.0
# Name: The Menu, dtype: object
# Progress: 0.56%
# Processing: https://www.rottentomatoes.com/m/the_banshees_of_inisherin/
# Processing: https://www.rottentomatoes.com/m/the_banshees_of_inisherin_2022/
# RT_audience_score             3.7
# RT_tomatometer_score         8.70
# RT_audience_#reviews       5620.0
# RT_tomatometer_#reviews     365.0
# Name: The Banshees of Inisherin, dtype: object
# Progress: 0.6%
# Processing: https://www.rottentomatoes.com/m/the_whale/
# Processing: https://www.rottentomatoes.com/m/the_whale_2022/
# RT_audience_score             4.2
# RT_tomatometer_score         6.60
# RT_audience_#reviews       5826.0
# RT_tomatometer_#reviews     341.0
# Name: The Whale, dtype: object
# Progress: 0.65%
# Processing: https://www.rottentomatoes.com/m/smile/
# Processing: https://www.rottentomatoes.com/m/smile_2022/
# RT_audience_score             3.7
# RT_tomatometer_score         6.60
# RT_audience_#reviews       8386.0
# RT_tomatometer_#reviews     192.0
# Name: Smile, dtype: object
# Progress: 0.69%
# Processing: https://www.rottentomatoes.com/m/dont_worry_darling/
# Processing: https://www.rottentomatoes.com/m/dont_worry_darling_2022/
# RT_audience_score              3.5
# RT_tomatometer_score          5.40
# RT_audience_#reviews       10088.0
# RT_tomatometer_#reviews      352.0
# Name: Don't Worry Darling, dtype: object
# Progress: 0.73%
# Processing: https://www.rottentomatoes.com/m/brahmastra_part_one_shiva/
# Processing: https://www.rottentomatoes.com/m/brahmastra_part_one_shiva_2022/
# RT_audience_score             3.4
# RT_tomatometer_score         5.70
# RT_audience_#reviews       3126.0
# RT_tomatometer_#reviews      35.0
# Name: Brahmastra Part One: Shiva, dtype: object
# Progress: 0.77%
# Processing: https://www.rottentomatoes.com/m/the_fabelmans/
# Processing: https://www.rottentomatoes.com/m/the_fabelmans_2022/
# RT_audience_score             3.9
# RT_tomatometer_score         8.20
# RT_audience_#reviews       4077.0
# RT_tomatometer_#reviews     390.0
# Name: The Fabelmans, dtype: object
# Progress: 0.81%
# Processing: https://www.rottentomatoes.com/m/amsterdam/
# Processing: https://www.rottentomatoes.com/m/amsterdam_2022/
# RT_audience_score             3.3
# RT_tomatometer_score         5.00
# RT_audience_#reviews       3498.0
# RT_tomatometer_#reviews     257.0
# Name: Amsterdam, dtype: object
# Progress: 0.85%
# Processing: https://www.rottentomatoes.com/m/tar/
# Processing: https://www.rottentomatoes.com/m/tar_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         8.30
# RT_audience_#reviews       2582.0
# RT_tomatometer_#reviews     348.0
# Name: Tár, dtype: object
# Progress: 0.89%
# Processing: https://www.rottentomatoes.com/m/pearl/
# Processing: https://www.rottentomatoes.com/m/pearl_2022/
# RT_audience_score             3.9
# RT_tomatometer_score         7.80
# RT_audience_#reviews       2727.0
# RT_tomatometer_#reviews     204.0
# Name: Pearl, dtype: object
# Progress: 0.93%
# Processing: https://www.rottentomatoes.com/m/laal_singh_chaddha/
# Processing: https://www.rottentomatoes.com/m/laal_singh_chaddha_2022/
# RT_audience_score             2.9
# RT_tomatometer_score         6.60
# RT_audience_#reviews       1952.0
# RT_tomatometer_#reviews      36.0
# Name: Laal Singh Chaddha, dtype: object
# Progress: 0.97%
# Processing: https://www.rottentomatoes.com/m/barbarian/
# Processing: https://www.rottentomatoes.com/m/barbarian_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         7.50
# RT_audience_#reviews       7327.0
# RT_tomatometer_#reviews     207.0
# Name: Barbarian, dtype: object
# Progress: 1.01%
# Processing: https://www.rottentomatoes.com/m/fall/
# Processing: https://www.rottentomatoes.com/m/fall_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         6.50
# RT_audience_#reviews       2231.0
# RT_tomatometer_#reviews     148.0
# Name: Fall, dtype: object
# Progress: 1.05%
# Processing: https://www.rottentomatoes.com/m/day_shift/
# Processing: https://www.rottentomatoes.com/m/day_shift_2022/
# RT_audience_score             4.1
# RT_tomatometer_score         5.70
# RT_audience_#reviews       3188.0
# RT_tomatometer_#reviews     137.0
# Name: Day Shift, dtype: object
# Progress: 1.09%
# Processing: https://www.rottentomatoes.com/m/bullet_train/
# Processing: https://www.rottentomatoes.com/m/bullet_train_2022/
# RT_audience_score              3.9
# RT_tomatometer_score          5.60
# RT_audience_#reviews       16305.0
# RT_tomatometer_#reviews      340.0
# Name: Bullet Train, dtype: object
# Progress: 1.13%
# Processing: https://www.rottentomatoes.com/m/nope/
# Processing: https://www.rottentomatoes.com/m/nope_2022/
# RT_audience_score              3.5
# RT_tomatometer_score          7.50
# RT_audience_#reviews       17588.0
# RT_tomatometer_#reviews      469.0
# Name: Nope, dtype: object
# Progress: 1.17%
# Processing: https://www.rottentomatoes.com/m/the_gray_man/
# Processing: https://www.rottentomatoes.com/m/the_gray_man_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         5.50
# RT_audience_#reviews       5608.0
# RT_tomatometer_#reviews     272.0
# Name: The Gray Man, dtype: object
# Progress: 1.21%
# Processing: https://www.rottentomatoes.com/m/prey/
# Processing: https://www.rottentomatoes.com/m/prey_2022/
# RT_audience_score             3.7
# RT_tomatometer_score         7.70
# RT_audience_#reviews       9092.0
# RT_tomatometer_#reviews     282.0
# Name: Prey, dtype: object
# Progress: 1.25%
# Processing: https://www.rottentomatoes.com/m/thor_love_and_thunder/
# Processing: https://www.rottentomatoes.com/m/thor_love_and_thunder_2022/
# RT_audience_score              3.4
# RT_tomatometer_score          6.40
# RT_audience_#reviews       41199.0
# RT_tomatometer_#reviews      446.0
# Name: Thor: Love and Thunder, dtype: object
# Progress: 1.29%
# Processing: https://www.rottentomatoes.com/m/hustle/
# Processing: https://www.rottentomatoes.com/m/hustle_2022/
# RT_audience_score             4.2
# RT_tomatometer_score         7.20
# RT_audience_#reviews       2343.0
# RT_tomatometer_#reviews     170.0
# Name: Hustle, dtype: object
# Progress: 1.33%
# Processing: https://www.rottentomatoes.com/m/lightyear/
# Processing: https://www.rottentomatoes.com/m/lightyear_2022/
# RT_audience_score              3.3
# RT_tomatometer_score          6.70
# RT_audience_#reviews       11819.0
# RT_tomatometer_#reviews      319.0
# Name: Lightyear, dtype: object
# Progress: 1.37%
# Processing: https://www.rottentomatoes.com/m/where_the_crawdads_sing/
# Processing: https://www.rottentomatoes.com/m/where_the_crawdads_sing_2022/
# RT_audience_score              4.5
# RT_tomatometer_score          5.20
# RT_audience_#reviews       12038.0
# RT_tomatometer_#reviews      219.0
# Name: Where the Crawdads Sing, dtype: object
# Progress: 1.41%
# Processing: https://www.rottentomatoes.com/m/minions_the_rise_of_gru/
# Processing: https://www.rottentomatoes.com/m/minions_the_rise_of_gru_2022/
# RT_audience_score              4.3
# RT_tomatometer_score          6.10
# RT_audience_#reviews       13839.0
# RT_tomatometer_#reviews      183.0
# Name: Minions: The Rise of Gru, dtype: object
# Progress: 1.45%
# Processing: https://www.rottentomatoes.com/m/top_gun_maverick/
# Processing: https://www.rottentomatoes.com/m/top_gun_maverick_2022/
# RT_audience_score              4.8
# RT_tomatometer_score          8.20
# RT_audience_#reviews       90611.0
# RT_tomatometer_#reviews      476.0
# Name: Top Gun: Maverick, dtype: object
# Progress: 1.49%
# Processing: https://www.rottentomatoes.com/m/doctor_strange_in_the_multiverse_of_madness/
# Processing: https://www.rottentomatoes.com/m/doctor_strange_in_the_multiverse_of_madness_2022/
# RT_audience_score              3.9
# RT_tomatometer_score          6.50
# RT_audience_#reviews       44326.0
# RT_tomatometer_#reviews      460.0
# Name: Doctor Strange in the Multiverse of Madness, dtype: object
# Progress: 1.53%
# Processing: https://www.rottentomatoes.com/m/elvis/
# Processing: https://www.rottentomatoes.com/m/elvis_2022/
# RT_audience_score              4.4
# RT_tomatometer_score          6.80
# RT_audience_#reviews       21054.0
# RT_tomatometer_#reviews      398.0
# Name: Elvis, dtype: object
# Progress: 1.57%
# Processing: https://www.rottentomatoes.com/m/jurassic_world_dominion/
# Processing: https://www.rottentomatoes.com/m/jurassic_world_dominion_2022/
# RT_audience_score              3.7
# RT_tomatometer_score          4.80
# RT_audience_#reviews       30166.0
# RT_tomatometer_#reviews      403.0
# Name: Jurassic World: Dominion, dtype: object
# Progress: 1.61%
# Processing: https://www.rottentomatoes.com/m/triangle_of_sadness/
# Processing: https://www.rottentomatoes.com/m/triangle_of_sadness_2022/
# RT_audience_score             3.5
# RT_tomatometer_score         7.20
# RT_audience_#reviews       2289.0
# RT_tomatometer_#reviews     276.0
# Name: Triangle of Sadness, dtype: object
# Progress: 1.65%
# Processing: https://www.rottentomatoes.com/m/the_northman/
# Processing: https://www.rottentomatoes.com/m/the_northman_2022/
# RT_audience_score             3.5
# RT_tomatometer_score         7.70
# RT_audience_#reviews       9319.0
# RT_tomatometer_#reviews     383.0
# Name: The Northman, dtype: object
# Progress: 1.69%
# Processing: https://www.rottentomatoes.com/m/fantastic_beasts_the_secrets_of_dumbledore/
# Processing: https://www.rottentomatoes.com/m/fantastic_beasts_the_secrets_of_dumbledore_2022/
# RT_audience_score              3.8
# RT_tomatometer_score          5.40
# RT_audience_#reviews       11769.0
# RT_tomatometer_#reviews      247.0
# Name: Fantastic Beasts: The Secrets of Dumbledore, dtype: object
# Progress: 1.73%
# Processing: https://www.rottentomatoes.com/m/the_batman/
# Processing: https://www.rottentomatoes.com/m/the_batman_2022/
# RT_audience_score              4.3
# RT_tomatometer_score          7.70
# RT_audience_#reviews       57942.0
# RT_tomatometer_#reviews      524.0
# Name: The Batman, dtype: object
# Progress: 1.77%
# Processing: https://www.rottentomatoes.com/m/everything_everywhere_all_at_once/
# Processing: https://www.rottentomatoes.com/m/everything_everywhere_all_at_once_2022/
# RT_audience_score              4.1
# RT_tomatometer_score          8.50
# RT_audience_#reviews       19803.0
# RT_tomatometer_#reviews      403.0
# Name: Everything Everywhere All at Once, dtype: object
# Progress: 1.81%
# Processing: https://www.rottentomatoes.com/m/rrr/
# Processing: https://www.rottentomatoes.com/m/rrr_2022/
# RT_audience_score             4.5
# RT_tomatometer_score         8.30
# RT_audience_#reviews       3223.0
# RT_tomatometer_#reviews     103.0
# Name: RRR, dtype: object
# Progress: 1.85%
# Processing: https://www.rottentomatoes.com/m/x/
# Processing: https://www.rottentomatoes.com/m/x_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         7.70
# RT_audience_#reviews       4612.0
# RT_tomatometer_#reviews     226.0
# Name: X, dtype: object
# Progress: 1.9%
# Processing: https://www.rottentomatoes.com/m/the_lost_city/
# Processing: https://www.rottentomatoes.com/m/the_lost_city_2022/
# RT_audience_score             3.8
# RT_tomatometer_score         6.40
# RT_audience_#reviews       8918.0
# RT_tomatometer_#reviews     273.0
# Name: The Lost City, dtype: object
# Progress: 1.94%
# Processing: https://www.rottentomatoes.com/m/morbius/
# Processing: https://www.rottentomatoes.com/m/morbius_2022/
# RT_audience_score              3.5
# RT_tomatometer_score          3.80
# RT_audience_#reviews       17951.0
# RT_tomatometer_#reviews      283.0
# Name: Morbius, dtype: object
# Progress: 1.98%
# Processing: https://www.rottentomatoes.com/m/turning_red/
# Processing: https://www.rottentomatoes.com/m/turning_red_2022/
# RT_audience_score             3.6
# RT_tomatometer_score         8.10
# RT_audience_#reviews       6585.0
# RT_tomatometer_#reviews     287.0
# Name: Turning Red, dtype: object
# Progress: 2.02%
# Processing: https://www.rottentomatoes.com/m/the_unbearable_weight_of_massive_talent/
# Processing: https://www.rottentomatoes.com/m/the_unbearable_weight_of_massive_talent_2022/
# RT_audience_score             4.1
# RT_tomatometer_score         7.30
# RT_audience_#reviews       4676.0
# RT_tomatometer_#reviews     314.0
# Name: The Unbearable Weight of Massive Talent, dtype: object
# Progress: 2.06%
# Processing: https://www.rottentomatoes.com/m/ambulance/
# Processing: https://www.rottentomatoes.com/m/ambulance_2022/
# RT_audience_score             3.8
# RT_tomatometer_score         5.80
# RT_audience_#reviews       4207.0
# RT_tomatometer_#reviews     251.0
# Name: Ambulance, dtype: object
# Progress: 2.1%
# Processing: https://www.rottentomatoes.com/m/sonic_the_hedgehog_2/
# Processing: https://www.rottentomatoes.com/m/sonic_the_hedgehog_2_2022/
# RT_audience_score              4.5
# RT_tomatometer_score          6.00
# RT_audience_#reviews       14552.0
# RT_tomatometer_#reviews      182.0
# Name: Sonic the Hedgehog 2, dtype: object
# Progress: 2.14%
# Processing: https://www.rottentomatoes.com/m/uncharted/
# Processing: https://www.rottentomatoes.com/m/uncharted_2022/
# RT_audience_score              3.9
# RT_tomatometer_score          5.20
# RT_audience_#reviews       14821.0
# RT_tomatometer_#reviews      264.0
# Name: Uncharted, dtype: object
# Progress: 2.18%
# Processing: https://www.rottentomatoes.com/m/the_adam_project/
# Processing: https://www.rottentomatoes.com/m/the_adam_project_2022/
# RT_audience_score             3.8
# RT_tomatometer_score         6.20
# RT_audience_#reviews       3240.0
# RT_tomatometer_#reviews     216.0
# Name: The Adam Project, dtype: object
# Progress: 2.22%
# Processing: https://www.rottentomatoes.com/m/death_on_the_nile/
# Processing: https://www.rottentomatoes.com/m/death_on_the_nile_2022/
# RT_audience_score             3.7
# RT_tomatometer_score         5.90
# RT_audience_#reviews       6132.0
# RT_tomatometer_#reviews     290.0
# Name: Death on the Nile, dtype: object
# Progress: 2.26%
# Processing: https://www.rottentomatoes.com/m/moonfall/
# Processing: https://www.rottentomatoes.com/m/moonfall_2022/
# RT_audience_score             3.1
# RT_tomatometer_score         4.40
# RT_audience_#reviews       4629.0
# RT_tomatometer_#reviews     216.0
# Name: Moonfall, dtype: object
# Progress: 2.3%
# Processing: https://www.rottentomatoes.com/m/namescream____screamscream____screamname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namescream____screamscream____screamname_name_dtype_object_Name
# Scream    2022
# Scream    1997
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Scream    Scream
# Scream    Scream
# Name: Name, dtype: object
# Progress: 2.34%
# Processing: https://www.rottentomatoes.com/m/spiderman_no_way_home/
# Processing: https://www.rottentomatoes.com/m/spiderman_no_way_home_2021/
# Could not scrape data for this movie: Spider-Man: No Way Home
# Progress: 2.38%
# Processing: https://www.rottentomatoes.com/m/dont_look_up/
# Processing: https://www.rottentomatoes.com/m/dont_look_up_2021/
# RT_audience_score              3.7
# RT_tomatometer_score          6.30
# RT_audience_#reviews       14082.0
# RT_tomatometer_#reviews      305.0
# Name: Don't Look Up, dtype: object
# Progress: 2.42%
# Processing: https://www.rottentomatoes.com/m/the_matrix_resurrections/
# Processing: https://www.rottentomatoes.com/m/the_matrix_resurrections_2021/
# RT_audience_score              2.8
# RT_tomatometer_score          6.20
# RT_audience_#reviews       15280.0
# RT_tomatometer_#reviews      361.0
# Name: The Matrix Resurrections, dtype: object
# Progress: 2.46%
# Processing: https://www.rottentomatoes.com/m/the_kings_man/
# Processing: https://www.rottentomatoes.com/m/the_kings_man_2021/
# RT_audience_score             3.6
# RT_tomatometer_score         5.10
# RT_audience_#reviews       5722.0
# RT_tomatometer_#reviews     183.0
# Name: The King's Man, dtype: object
# Progress: 2.5%
# Processing: https://www.rottentomatoes.com/m/nightmare_alley/
# Processing: https://www.rottentomatoes.com/m/nightmare_alley_2021/
# RT_audience_score             3.6
# RT_tomatometer_score         7.40
# RT_audience_#reviews       4002.0
# RT_tomatometer_#reviews     355.0
# Name: Nightmare Alley, dtype: object
# Progress: 2.54%
# Processing: https://www.rottentomatoes.com/m/red_notice/
# Processing: https://www.rottentomatoes.com/m/red_notice_2021/
# RT_audience_score             3.6
# RT_tomatometer_score         4.80
# RT_audience_#reviews       6462.0
# RT_tomatometer_#reviews     175.0
# Name: Red Notice, dtype: object
# Progress: 2.58%
# Processing: https://www.rottentomatoes.com/m/encanto/
# Processing: https://www.rottentomatoes.com/m/encanto_2021/
# RT_audience_score              4.2
# RT_tomatometer_score          7.50
# RT_audience_#reviews       10422.0
# RT_tomatometer_#reviews      212.0
# Name: Encanto, dtype: object
# Progress: 2.62%
# Processing: https://www.rottentomatoes.com/m/house_of_gucci/
# Processing: https://www.rottentomatoes.com/m/house_of_gucci_2021/
# RT_audience_score             3.9
# RT_tomatometer_score         6.20
# RT_audience_#reviews       7626.0
# RT_tomatometer_#reviews     370.0
# Name: House of Gucci, dtype: object
# Progress: 2.66%
# Processing: https://www.rottentomatoes.com/m/licorice_pizza/
# Processing: https://www.rottentomatoes.com/m/licorice_pizza_2021/
# RT_audience_score             3.4
# RT_tomatometer_score         8.30
# RT_audience_#reviews       3737.0
# RT_tomatometer_#reviews     325.0
# Name: Licorice Pizza, dtype: object
# Progress: 2.7%
# Processing: https://www.rottentomatoes.com/m/the_unforgivable/
# Processing: https://www.rottentomatoes.com/m/the_unforgivable_2021/
# RT_audience_score             3.8
# RT_tomatometer_score         5.10
# RT_audience_#reviews       1554.0
# RT_tomatometer_#reviews      92.0
# Name: The Unforgivable, dtype: object
# Progress: 2.74%
# Processing: https://www.rottentomatoes.com/m/finch/
# Processing: https://www.rottentomatoes.com/m/finch_2021/
# RT_audience_score             3.6
# RT_tomatometer_score         6.50
# RT_audience_#reviews       1376.0
# RT_tomatometer_#reviews     173.0
# Name: Finch, dtype: object
# Progress: 2.78%
# Processing: https://www.rottentomatoes.com/m/west_side_story/
# Processing: https://www.rottentomatoes.com/m/west_side_story_2021/
# RT_audience_score             4.3
# RT_tomatometer_score         8.20
# RT_audience_#reviews       7240.0
# RT_tomatometer_#reviews     389.0
# Name: West Side Story, dtype: object
# Progress: 2.82%
# Processing: https://www.rottentomatoes.com/m/sing_2/
# Processing: https://www.rottentomatoes.com/m/sing_2_2021/
# RT_audience_score             4.7
# RT_tomatometer_score         6.10
# RT_audience_#reviews       9642.0
# RT_tomatometer_#reviews     137.0
# Name: Sing 2, dtype: object
# Progress: 2.86%
# Processing: https://www.rottentomatoes.com/m/eternals/
# Processing: https://www.rottentomatoes.com/m/eternals_2021/
# RT_audience_score              3.8
# RT_tomatometer_score          5.60
# RT_audience_#reviews       47274.0
# RT_tomatometer_#reviews      413.0
# Name: Eternals, dtype: object
# Progress: 2.9%
# Processing: https://www.rottentomatoes.com/m/ghostbusters_afterlife/
# Processing: https://www.rottentomatoes.com/m/ghostbusters_afterlife_2021/
# RT_audience_score              4.4
# RT_tomatometer_score          6.20
# RT_audience_#reviews       17821.0
# RT_tomatometer_#reviews      310.0
# Name: Ghostbusters: Afterlife, dtype: object
# Progress: 2.94%
# Processing: https://www.rottentomatoes.com/m/namedune____dunedune____dunename_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namedune____dunedune____dunename_name_dtype_object_Name
# Dune    2021
# Dune    1984
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Dune    Dune
# Dune    Dune
# Name: Name, dtype: object
# Progress: 2.98%
# Processing: https://www.rottentomatoes.com/m/no_time_to_die/
# Processing: https://www.rottentomatoes.com/m/no_time_to_die_2021/
# RT_audience_score              4.1
# RT_tomatometer_score          7.30
# RT_audience_#reviews       19099.0
# RT_tomatometer_#reviews      432.0
# Name: No Time to Die, dtype: object
# Progress: 3.02%
# Processing: https://www.rottentomatoes.com/m/venom_let_there_be_carnage/
# Processing: https://www.rottentomatoes.com/m/venom_let_there_be_carnage_2021/
# RT_audience_score              3.8
# RT_tomatometer_score          5.40
# RT_audience_#reviews       18526.0
# RT_tomatometer_#reviews      281.0
# Name: Venom: Let There Be Carnage, dtype: object
# Progress: 3.06%
# Processing: https://www.rottentomatoes.com/m/the_power_of_the_dog/
# Processing: https://www.rottentomatoes.com/m/the_power_of_the_dog_2021/
# RT_audience_score             3.2
# RT_tomatometer_score         8.40
# RT_audience_#reviews       4621.0
# RT_tomatometer_#reviews     362.0
# Name: The Power of the Dog, dtype: object
# Progress: 3.1%
# Processing: https://www.rottentomatoes.com/m/the_black_phone/
# Processing: https://www.rottentomatoes.com/m/the_black_phone_2022/
# RT_audience_score              4.2
# RT_tomatometer_score          7.00
# RT_audience_#reviews       10456.0
# RT_tomatometer_#reviews      264.0
# Name: The Black Phone, dtype: object
# Progress: 3.15%
# Processing: https://www.rottentomatoes.com/m/the_last_duel/
# Processing: https://www.rottentomatoes.com/m/the_last_duel_2021/
# RT_audience_score             3.8
# RT_tomatometer_score         7.30
# RT_audience_#reviews       4562.0
# RT_tomatometer_#reviews     292.0
# Name: The Last Duel, dtype: object
# Progress: 3.19%
# Processing: https://www.rottentomatoes.com/m/last_night_in_soho/
# Processing: https://www.rottentomatoes.com/m/last_night_in_soho_2021/
# RT_audience_score             3.9
# RT_tomatometer_score         6.90
# RT_audience_#reviews       3902.0
# RT_tomatometer_#reviews     351.0
# Name: Last Night in Soho, dtype: object
# Progress: 3.23%
# Processing: https://www.rottentomatoes.com/m/the_guilty/
# Processing: https://www.rottentomatoes.com/m/the_guilty_2021/
# RT_audience_score               3
# RT_tomatometer_score         6.50
# RT_audience_#reviews       1630.0
# RT_tomatometer_#reviews     190.0
# Name: The Guilty, dtype: object
# Progress: 3.27%
# Processing: https://www.rottentomatoes.com/m/king_richard/
# Processing: https://www.rottentomatoes.com/m/king_richard_2021/
# RT_audience_score             4.2
# RT_tomatometer_score         7.60
# RT_audience_#reviews       4021.0
# RT_tomatometer_#reviews     299.0
# Name: King Richard, dtype: object
# Progress: 3.31%
# Processing: https://www.rottentomatoes.com/m/malignant/
# Processing: https://www.rottentomatoes.com/m/malignant_2021/
# RT_audience_score             3.1
# RT_tomatometer_score         6.30
# RT_audience_#reviews       4220.0
# RT_tomatometer_#reviews     178.0
# Name: Malignant, dtype: object
# Progress: 3.35%
# Processing: https://www.rottentomatoes.com/m/halloween_kills/
# Processing: https://www.rottentomatoes.com/m/halloween_kills_2021/
# RT_audience_score              3.3
# RT_tomatometer_score          5.00
# RT_audience_#reviews       10385.0
# RT_tomatometer_#reviews      278.0
# Name: Halloween Kills, dtype: object
# Progress: 3.39%
# Processing: https://www.rottentomatoes.com/m/belfast/
# Processing: https://www.rottentomatoes.com/m/belfast_2021/
# RT_audience_score             4.1
# RT_tomatometer_score         7.80
# RT_audience_#reviews       3024.0
# RT_tomatometer_#reviews     333.0
# Name: Belfast, dtype: object
# Progress: 3.43%
# Processing: https://www.rottentomatoes.com/m/farha/
# Processing: https://www.rottentomatoes.com/m/farha_2022/
# RT_audience_score            4.7
# RT_tomatometer_score        7.10
# RT_audience_#reviews       176.0
# RT_tomatometer_#reviews     10.0
# Name: Farha, dtype: object
# Progress: 3.47%
# Processing: https://www.rottentomatoes.com/m/shangchi_and_the_legend_of_the_ten_rings/
# Processing: https://www.rottentomatoes.com/m/shangchi_and_the_legend_of_the_ten_rings_2021/
# Could not scrape data for this movie: Shang-Chi and the Legend of the Ten Rings
# Progress: 3.51%
# Processing: https://www.rottentomatoes.com/m/free_guy/
# Processing: https://www.rottentomatoes.com/m/free_guy_2021/
# RT_audience_score              4.3
# RT_tomatometer_score          7.00
# RT_audience_#reviews       15264.0
# RT_tomatometer_#reviews      297.0
# Name: Free Guy, dtype: object
# Progress: 3.55%
# Processing: https://www.rottentomatoes.com/m/the_suicide_squad/
# Processing: https://www.rottentomatoes.com/m/the_suicide_squad_2021/
# RT_audience_score              3.9
# RT_tomatometer_score          7.50
# RT_audience_#reviews       16449.0
# RT_tomatometer_#reviews      383.0
# Name: The Suicide Squad, dtype: object
# Progress: 3.59%
# Processing: https://www.rottentomatoes.com/m/jungle_cruise/
# Processing: https://www.rottentomatoes.com/m/jungle_cruise_2021/
# RT_audience_score              4.2
# RT_tomatometer_score          6.00
# RT_audience_#reviews       15084.0
# RT_tomatometer_#reviews      347.0
# Name: Jungle Cruise, dtype: object
# Progress: 3.63%
# Processing: https://www.rottentomatoes.com/m/old/
# Processing: https://www.rottentomatoes.com/m/old_2021/
# RT_audience_score             2.9
# RT_tomatometer_score         5.50
# RT_audience_#reviews       5818.0
# RT_tomatometer_#reviews     344.0
# Name: Old, dtype: object
# Progress: 3.67%
# Processing: https://www.rottentomatoes.com/m/the_french_dispatch/
# Processing: https://www.rottentomatoes.com/m/the_french_dispatch_2021/
# RT_audience_score             3.7
# RT_tomatometer_score         7.10
# RT_audience_#reviews       3074.0
# RT_tomatometer_#reviews     319.0
# Name: The French Dispatch, dtype: object
# Progress: 3.71%
# Processing: https://www.rottentomatoes.com/m/the_green_knight/
# Processing: https://www.rottentomatoes.com/m/the_green_knight_2021/
# RT_audience_score               3
# RT_tomatometer_score         8.00
# RT_audience_#reviews       5434.0
# RT_tomatometer_#reviews     332.0
# Name: The Green Knight, dtype: object
# Progress: 3.75%
# Processing: https://www.rottentomatoes.com/m/pig/
# Processing: https://www.rottentomatoes.com/m/pig_2021/
# RT_audience_score             3.8
# RT_tomatometer_score         8.20
# RT_audience_#reviews       2789.0
# RT_tomatometer_#reviews     273.0
# Name: Pig, dtype: object
# Progress: 3.79%
# Processing: https://www.rottentomatoes.com/m/black_widow/
# Processing: https://www.rottentomatoes.com/m/black_widow_2021/
# RT_audience_score                4
# RT_tomatometer_score          6.90
# RT_audience_#reviews       30168.0
# RT_tomatometer_#reviews      456.0
# Name: Black Widow, dtype: object
# Progress: 3.83%
# Processing: https://www.rottentomatoes.com/m/the_tomorrow_war/
# Processing: https://www.rottentomatoes.com/m/the_tomorrow_war_2021/
# RT_audience_score             3.9
# RT_tomatometer_score         5.70
# RT_audience_#reviews       7093.0
# RT_tomatometer_#reviews     210.0
# Name: The Tomorrow War, dtype: object
# Progress: 3.87%
# Processing: https://www.rottentomatoes.com/m/luca/
# Processing: https://www.rottentomatoes.com/m/luca_2021/
# RT_audience_score             4.1
# RT_tomatometer_score         7.30
# RT_audience_#reviews       3377.0
# RT_tomatometer_#reviews     304.0
# Name: Luca, dtype: object
# Progress: 3.91%
# Processing: https://www.rottentomatoes.com/m/hitmans_wifes_bodyguard/
# Processing: https://www.rottentomatoes.com/m/hitmans_wifes_bodyguard_2021/
# Could not scrape data for this movie: Hitman's Wife's Bodyguard
# Progress: 3.95%
# Processing: https://www.rottentomatoes.com/m/fear_street_part_one__1994/
# Processing: https://www.rottentomatoes.com/m/fear_street_part_one__1994_2021/
# Could not scrape data for this movie: Fear Street: Part One - 1994
# Progress: 3.99%
# Processing: https://www.rottentomatoes.com/m/cruella/
# Processing: https://www.rottentomatoes.com/m/cruella_2021/
# RT_audience_score              4.4
# RT_tomatometer_score          6.80
# RT_audience_#reviews       14747.0
# RT_tomatometer_#reviews      412.0
# Name: Cruella, dtype: object
# Progress: 4.03%
# Processing: https://www.rottentomatoes.com/m/army_of_the_dead/
# Processing: https://www.rottentomatoes.com/m/army_of_the_dead_2021/
# RT_audience_score             3.1
# RT_tomatometer_score         6.10
# RT_audience_#reviews       6416.0
# RT_tomatometer_#reviews     288.0
# Name: Army of the Dead, dtype: object
# Progress: 4.07%
# Processing: https://www.rottentomatoes.com/m/f9_the_fast_saga/
# Processing: https://www.rottentomatoes.com/m/f9_the_fast_saga_2021/
# Could not scrape data for this movie: F9: The Fast Saga
# Progress: 4.11%
# Processing: https://www.rottentomatoes.com/m/the_conjuring_the_devil_made_me_do_it/
# Processing: https://www.rottentomatoes.com/m/the_conjuring_the_devil_made_me_do_it_2021/
# RT_audience_score             3.8
# RT_tomatometer_score         5.80
# RT_audience_#reviews       5969.0
# RT_tomatometer_#reviews     256.0
# Name: The Conjuring: The Devil Made Me Do It, dtype: object
# Progress: 4.15%
# Processing: https://www.rottentomatoes.com/m/the_woman_in_the_window/
# Processing: https://www.rottentomatoes.com/m/the_woman_in_the_window_2021/
# Could not scrape data for this movie: The Woman in the Window
# Progress: 4.19%
# Processing: https://www.rottentomatoes.com/m/wrath_of_man/
# Processing: https://www.rottentomatoes.com/m/wrath_of_man_2021/
# RT_audience_score             4.3
# RT_tomatometer_score         6.30
# RT_audience_#reviews       4762.0
# RT_tomatometer_#reviews     259.0
# Name: Wrath of Man, dtype: object
# Progress: 4.23%
# Processing: https://www.rottentomatoes.com/m/namemortal_kombat____mortal_kombatmortal_kombat____mortal_kombatname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namemortal_kombat____mortal_kombatmortal_kombat____mortal_kombatname_name_dtype_object_Name
# Mortal Kombat    2021
# Mortal Kombat    1995
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Mortal Kombat    Mortal Kombat
# Mortal Kombat    Mortal Kombat
# Name: Name, dtype: object
# Progress: 4.27%
# Processing: https://www.rottentomatoes.com/m/the_mitchells_vs_the_machines/
# Processing: https://www.rottentomatoes.com/m/the_mitchells_vs_the_machines_2021/
# RT_audience_score             4.3
# RT_tomatometer_score         8.20
# RT_audience_#reviews       2676.0
# RT_tomatometer_#reviews     213.0
# Name: The Mitchells vs the Machines, dtype: object
# Progress: 4.31%
# Processing: https://www.rottentomatoes.com/m/zack_snyders_justice_league/
# Processing: https://www.rottentomatoes.com/m/zack_snyders_justice_league_2021/
# RT_audience_score              4.6
# RT_tomatometer_score          6.70
# RT_audience_#reviews       46235.0
# RT_tomatometer_#reviews      313.0
# Name: Zack Snyder's Justice League, dtype: object
# Progress: 4.35%
# Processing: https://www.rottentomatoes.com/m/nobody/
# Processing: https://www.rottentomatoes.com/m/nobody_2021/
# RT_audience_score              4.3
# RT_tomatometer_score          7.00
# RT_audience_#reviews       10222.0
# RT_tomatometer_#reviews      286.0
# Name: Nobody, dtype: object
# Progress: 4.4%
# Processing: https://www.rottentomatoes.com/m/godzilla_vs_kong/
# Processing: https://www.rottentomatoes.com/m/godzilla_vs_kong_2021/
# RT_audience_score              4.1
# RT_tomatometer_score          6.40
# RT_audience_#reviews       20444.0
# RT_tomatometer_#reviews      392.0
# Name: Godzilla vs. Kong, dtype: object
# Progress: 4.44%
# Processing: https://www.rottentomatoes.com/m/raya_and_the_last_dragon/
# Processing: https://www.rottentomatoes.com/m/raya_and_the_last_dragon_2021/
# RT_audience_score             4.2
# RT_tomatometer_score         7.70
# RT_audience_#reviews       7873.0
# RT_tomatometer_#reviews     303.0
# Name: Raya and the Last Dragon, dtype: object
# Progress: 4.48%
# Processing: https://www.rottentomatoes.com/m/judas_and_the_black_messiah/
# Processing: https://www.rottentomatoes.com/m/judas_and_the_black_messiah_2021/
# RT_audience_score             4.1
# RT_tomatometer_score         8.20
# RT_audience_#reviews       2913.0
# RT_tomatometer_#reviews     356.0
# Name: Judas and the Black Messiah, dtype: object
# Progress: 4.52%
# Processing: https://www.rottentomatoes.com/m/coda/
# Processing: https://www.rottentomatoes.com/m/coda_2021/
# RT_audience_score             4.3
# RT_tomatometer_score         7.80
# RT_audience_#reviews       2385.0
# RT_tomatometer_#reviews     294.0
# Name: CODA, dtype: object
# Progress: 4.56%
# Processing: https://www.rottentomatoes.com/m/the_little_things/
# Processing: https://www.rottentomatoes.com/m/the_little_things_2021/
# RT_audience_score             3.2
# RT_tomatometer_score         5.40
# RT_audience_#reviews       4474.0
# RT_tomatometer_#reviews     266.0
# Name: The Little Things, dtype: object
# Progress: 4.6%
# Processing: https://www.rottentomatoes.com/m/wonder_woman_1984/
# Processing: https://www.rottentomatoes.com/m/wonder_woman_1984_2020/
# RT_audience_score              2.7
# RT_tomatometer_score          6.10
# RT_audience_#reviews       27533.0
# RT_tomatometer_#reviews      451.0
# Name: Wonder Woman 1984, dtype: object
# Progress: 4.64%
# Processing: https://www.rottentomatoes.com/m/news_of_the_world/
# Processing: https://www.rottentomatoes.com/m/news_of_the_world_2020/
# RT_audience_score               4
# RT_tomatometer_score         7.40
# RT_audience_#reviews       3807.0
# RT_tomatometer_#reviews     273.0
# Name: News of the World, dtype: object
# Progress: 4.68%
# Processing: https://www.rottentomatoes.com/m/the_midnight_sky/
# Processing: https://www.rottentomatoes.com/m/the_midnight_sky_2020/
# RT_audience_score             2.3
# RT_tomatometer_score         5.70
# RT_audience_#reviews       2612.0
# RT_tomatometer_#reviews     252.0
# Name: The Midnight Sky, dtype: object
# Progress: 4.72%
# Processing: https://www.rottentomatoes.com/m/mank/
# Processing: https://www.rottentomatoes.com/m/mank_2020/
# RT_audience_score             3.4
# RT_tomatometer_score         7.60
# RT_audience_#reviews       1980.0
# RT_tomatometer_#reviews     354.0
# Name: Mank, dtype: object
# Progress: 4.76%
# Processing: https://www.rottentomatoes.com/m/soul/
# Processing: https://www.rottentomatoes.com/m/soul_2020/
# RT_audience_score             4.2
# RT_tomatometer_score         8.30
# RT_audience_#reviews       7669.0
# RT_tomatometer_#reviews     360.0
# Name: Soul, dtype: object
# Progress: 4.8%
# Processing: https://www.rottentomatoes.com/m/borat_subsequent_moviefilm/
# Processing: https://www.rottentomatoes.com/m/borat_subsequent_moviefilm_2020/
# RT_audience_score             3.3
# RT_tomatometer_score         7.20
# RT_audience_#reviews       3349.0
# RT_tomatometer_#reviews     307.0
# Name: Borat Subsequent Moviefilm, dtype: object
# Progress: 4.84%
# Processing: https://www.rottentomatoes.com/m/love_and_monsters/
# Processing: https://www.rottentomatoes.com/m/love_and_monsters_2021/
# RT_audience_score             4.1
# RT_tomatometer_score         7.30
# RT_audience_#reviews       2853.0
# RT_tomatometer_#reviews     116.0
# Name: Love and Monsters, dtype: object
# Progress: 4.88%
# Processing: https://www.rottentomatoes.com/m/enola_holmes/
# Processing: https://www.rottentomatoes.com/m/enola_holmes_2020/
# RT_audience_score             3.7
# RT_tomatometer_score         7.10
# RT_audience_#reviews       4679.0
# RT_tomatometer_#reviews     210.0
# Name: Enola Holmes, dtype: object
# Progress: 4.92%
# Processing: https://www.rottentomatoes.com/m/the_trial_of_the_chicago_7/
# Processing: https://www.rottentomatoes.com/m/the_trial_of_the_chicago_7_2020/
# RT_audience_score             4.2
# RT_tomatometer_score         7.80
# RT_audience_#reviews       2836.0
# RT_tomatometer_#reviews     343.0
# Name: The Trial of the Chicago 7, dtype: object
# Progress: 4.96%
# Processing: https://www.rottentomatoes.com/m/another_round/
# Processing: https://www.rottentomatoes.com/m/another_round_2020/
# RT_audience_score             4.1
# RT_tomatometer_score         7.90
# RT_audience_#reviews       1383.0
# RT_tomatometer_#reviews     228.0
# Name: Another Round, dtype: object
# Progress: 5.0%
# Processing: https://www.rottentomatoes.com/m/nomadland/
# Processing: https://www.rottentomatoes.com/m/nomadland_2021/
# RT_audience_score             3.7
# RT_tomatometer_score         8.80
# RT_audience_#reviews       3996.0
# RT_tomatometer_#reviews     436.0
# Name: Nomadland, dtype: object
# Progress: 5.04%
# Processing: https://www.rottentomatoes.com/m/the_devil_all_the_time/
# Processing: https://www.rottentomatoes.com/m/the_devil_all_the_time_2020/
# RT_audience_score             3.9
# RT_tomatometer_score         6.40
# RT_audience_#reviews       3257.0
# RT_tomatometer_#reviews     219.0
# Name: The Devil All the Time, dtype: object
# Progress: 5.08%
# Processing: https://www.rottentomatoes.com/m/i_care_a_lot/
# Processing: https://www.rottentomatoes.com/m/i_care_a_lot_2021/
# RT_audience_score             2.3
# RT_tomatometer_score         7.00
# RT_audience_#reviews       5048.0
# RT_tomatometer_#reviews     236.0
# Name: I Care a Lot, dtype: object
# Progress: 5.12%
# Processing: https://www.rottentomatoes.com/m/tenet/
# Processing: https://www.rottentomatoes.com/m/tenet_2020/
# RT_audience_score              3.7
# RT_tomatometer_score          6.90
# RT_audience_#reviews       17886.0
# RT_tomatometer_#reviews      375.0
# Name: Tenet, dtype: object
# Progress: 5.16%
# Processing: https://www.rottentomatoes.com/m/im_thinking_of_ending_things/
# Processing: https://www.rottentomatoes.com/m/im_thinking_of_ending_things_2020/
# RT_audience_score             2.9
# RT_tomatometer_score         7.60
# RT_audience_#reviews       2179.0
# RT_tomatometer_#reviews     269.0
# Name: I'm Thinking of Ending Things, dtype: object
# Progress: 5.2%
# Processing: https://www.rottentomatoes.com/m/project_power/
# Processing: https://www.rottentomatoes.com/m/project_power_2020/
# RT_audience_score             3.1
# RT_tomatometer_score         5.60
# RT_audience_#reviews       1718.0
# RT_tomatometer_#reviews     183.0
# Name: Project Power, dtype: object
# Progress: 5.24%
# Processing: https://www.rottentomatoes.com/m/the_new_mutants/
# Processing: https://www.rottentomatoes.com/m/the_new_mutants_2020/
# RT_audience_score             3.1
# RT_tomatometer_score         4.80
# RT_audience_#reviews       6675.0
# RT_tomatometer_#reviews     139.0
# Name: The New Mutants, dtype: object
# Progress: 5.28%
# Processing: https://www.rottentomatoes.com/m/the_old_guard/
# Processing: https://www.rottentomatoes.com/m/the_old_guard_2020/
# RT_audience_score             3.7
# RT_tomatometer_score         6.40
# RT_audience_#reviews       3806.0
# RT_tomatometer_#reviews     287.0
# Name: The Old Guard, dtype: object
# Progress: 5.32%
# Processing: https://www.rottentomatoes.com/m/greenland/
# Processing: https://www.rottentomatoes.com/m/greenland_2020/
# RT_audience_score             3.4
# RT_tomatometer_score         6.30
# RT_audience_#reviews       2403.0
# RT_tomatometer_#reviews     162.0
# Name: Greenland, dtype: object
# Progress: 5.36%
# Processing: https://www.rottentomatoes.com/m/greyhound/
# Processing: https://www.rottentomatoes.com/m/greyhound_2020/
# RT_audience_score             3.8
# RT_tomatometer_score         6.50
# RT_audience_#reviews       2147.0
# RT_tomatometer_#reviews     239.0
# Name: Greyhound, dtype: object
# Progress: 5.4%
# Processing: https://www.rottentomatoes.com/m/hamilton/
# Processing: https://www.rottentomatoes.com/m/hamilton_2020/
# RT_audience_score             4.4
# RT_tomatometer_score         9.10
# RT_audience_#reviews       2292.0
# RT_tomatometer_#reviews     202.0
# Name: Hamilton, dtype: object
# Progress: 5.44%
# Processing: https://www.rottentomatoes.com/m/eurovision_song_contest_the_story_of_fire_saga/
# Processing: https://www.rottentomatoes.com/m/eurovision_song_contest_the_story_of_fire_saga_2020/
# RT_audience_score             3.9
# RT_tomatometer_score         5.80
# RT_audience_#reviews       3148.0
# RT_tomatometer_#reviews     183.0
# Name: Eurovision Song Contest: The Story of Fire Saga, dtype: object
# Progress: 5.48%
# Processing: https://www.rottentomatoes.com/m/extraction/
# Processing: https://www.rottentomatoes.com/m/extraction_2020/
# RT_audience_score             3.6
# RT_tomatometer_score         6.20
# RT_audience_#reviews       5051.0
# RT_tomatometer_#reviews     219.0
# Name: Extraction, dtype: object
# Progress: 5.52%
# Processing: https://www.rottentomatoes.com/m/run/
# Processing: https://www.rottentomatoes.com/m/run_2020/
# RT_audience_score             3.7
# RT_tomatometer_score         7.10
# RT_audience_#reviews       1630.0
# RT_tomatometer_#reviews     141.0
# Name: Run, dtype: object
# Progress: 5.56%
# Processing: https://www.rottentomatoes.com/m/a_quiet_place_part_ii/
# Processing: https://www.rottentomatoes.com/m/a_quiet_place_part_ii_2021/
# RT_audience_score              4.3
# RT_tomatometer_score          7.50
# RT_audience_#reviews       14865.0
# RT_tomatometer_#reviews      369.0
# Name: A Quiet Place Part II, dtype: object
# Progress: 5.6%
# Processing: https://www.rottentomatoes.com/m/namemulan____mulanmulan____mulanname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namemulan____mulanmulan____mulanname_name_dtype_object_Name
# Mulan    2020
# Mulan    1998
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Mulan    Mulan
# Mulan    Mulan
# Name: Name, dtype: object
# Progress: 5.65%
# Processing: https://www.rottentomatoes.com/m/namethe_hunt____the_huntthe_hunt____the_huntname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namethe_hunt____the_huntthe_hunt____the_huntname_name_dtype_object_Name
# The Hunt    2020
# The Hunt    2013
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# The Hunt    The Hunt
# The Hunt    The Hunt
# Name: Name, dtype: object
# Progress: 5.69%
# Processing: https://www.rottentomatoes.com/m/spenser_confidential/
# Processing: https://www.rottentomatoes.com/m/spenser_confidential_2020/
# RT_audience_score             3.2
# RT_tomatometer_score         4.60
# RT_audience_#reviews       1403.0
# RT_tomatometer_#reviews      86.0
# Name: Spenser Confidential, dtype: object
# Progress: 5.73%
# Processing: https://www.rottentomatoes.com/m/bloodshot/
# Processing: https://www.rottentomatoes.com/m/bloodshot_2020/
# RT_audience_score             3.6
# RT_tomatometer_score         4.60
# RT_audience_#reviews       4083.0
# RT_tomatometer_#reviews     172.0
# Name: Bloodshot, dtype: object
# Progress: 5.77%
# Processing: https://www.rottentomatoes.com/m/the_invisible_man/
# Processing: https://www.rottentomatoes.com/m/the_invisible_man_2020/
# RT_audience_score              4.1
# RT_tomatometer_score          7.70
# RT_audience_#reviews       21078.0
# RT_tomatometer_#reviews      423.0
# Name: The Invisible Man, dtype: object
# Progress: 5.81%
# Processing: https://www.rottentomatoes.com/m/onward/
# Processing: https://www.rottentomatoes.com/m/onward_2020/
# RT_audience_score              4.4
# RT_tomatometer_score          7.20
# RT_audience_#reviews       14882.0
# RT_tomatometer_#reviews      349.0
# Name: Onward, dtype: object
# Progress: 5.85%
# Processing: https://www.rottentomatoes.com/m/birds_of_prey_and_the_fantabulous_emancipation_of_one_harley_quinn/
# Processing: https://www.rottentomatoes.com/m/birds_of_prey_and_the_fantabulous_emancipation_of_one_harley_quinn_2020/
# RT_audience_score              3.6
# RT_tomatometer_score          6.80
# RT_audience_#reviews       34270.0
# RT_tomatometer_#reviews      446.0
# Name: Birds of Prey and the Fantabulous Emancipation of One Harley Quinn, dtype: object
# Progress: 5.89%
# Processing: https://www.rottentomatoes.com/m/promising_young_woman/
# Processing: https://www.rottentomatoes.com/m/promising_young_woman_2020/
# RT_audience_score             4.1
# RT_tomatometer_score         8.10
# RT_audience_#reviews       5172.0
# RT_tomatometer_#reviews     427.0
# Name: Promising Young Woman, dtype: object
# Progress: 5.93%
# Processing: https://www.rottentomatoes.com/m/the_father/
# Processing: https://www.rottentomatoes.com/m/the_father_2021/
# RT_audience_score             4.3
# RT_tomatometer_score         8.70
# RT_audience_#reviews       2386.0
# RT_tomatometer_#reviews     294.0
# Name: The Father, dtype: object
# Progress: 5.97%
# Processing: https://www.rottentomatoes.com/m/palm_springs/
# Processing: https://www.rottentomatoes.com/m/palm_springs_2020/
# RT_audience_score             4.1
# RT_tomatometer_score         8.00
# RT_audience_#reviews       3105.0
# RT_tomatometer_#reviews     254.0
# Name: Palm Springs, dtype: object
# Progress: 6.01%
# Processing: https://www.rottentomatoes.com/m/bad_boys_for_life/
# Processing: https://www.rottentomatoes.com/m/bad_boys_for_life_2020/
# RT_audience_score              4.6
# RT_tomatometer_score          6.20
# RT_audience_#reviews       52359.0
# RT_tomatometer_#reviews      268.0
# Name: Bad Boys for Life, dtype: object
# Progress: 6.05%
# Processing: https://www.rottentomatoes.com/m/sonic_the_hedgehog/
# Processing: https://www.rottentomatoes.com/m/sonic_the_hedgehog_2020/
# RT_audience_score              4.4
# RT_tomatometer_score          5.90
# ...
# RT_audience_score              4.1
# RT_tomatometer_score          8.20
# RT_audience_#reviews       43628.0
# RT_tomatometer_#reviews      101.0
# Name: Kramer vs. Kramer, dtype: object
# Progress: 97.98%
# Processing: https://www.rottentomatoes.com/m/star_trek_the_motion_picture/
# Processing: https://www.rottentomatoes.com/m/star_trek_the_motion_picture_1979/
# RT_audience_score              3.1
# RT_tomatometer_score          6.00
# RT_audience_#reviews       66219.0
# RT_tomatometer_#reviews       56.0
# Name: Star Trek: The Motion Picture, dtype: object
# Progress: 98.02%
# Processing: https://www.rottentomatoes.com/m/life_of_brian/
# Processing: https://www.rottentomatoes.com/m/life_of_brian_1979/
# Could not scrape data for this movie: Life of Brian
# Progress: 98.06%
# Processing: https://www.rottentomatoes.com/m/rocky_ii/
# Processing: https://www.rottentomatoes.com/m/rocky_ii_1979/
# RT_audience_score                 4
# RT_tomatometer_score           6.70
# RT_audience_#reviews       346835.0
# RT_tomatometer_#reviews        33.0
# Name: Rocky II, dtype: object
# Progress: 98.1%
# Processing: https://www.rottentomatoes.com/m/escape_from_alcatraz/
# Processing: https://www.rottentomatoes.com/m/escape_from_alcatraz_1979/
# RT_audience_score              3.9
# RT_tomatometer_score          7.10
# RT_audience_#reviews       65523.0
# RT_tomatometer_#reviews       31.0
# Name: Escape from Alcatraz, dtype: object
# Progress: 98.15%
# Processing: https://www.rottentomatoes.com/m/moonraker/
# Processing: https://www.rottentomatoes.com/m/moonraker_1979/
# RT_audience_score           3.3
# RT_tomatometer_score        N/A
# RT_audience_#reviews       21.0
# RT_tomatometer_#reviews     1.0
# Name: Moonraker, dtype: object
# Progress: 98.19%
# Processing: https://www.rottentomatoes.com/m/alien/
# Processing: https://www.rottentomatoes.com/m/alien_1979/
# RT_audience_score               4.4
# RT_tomatometer_score           9.10
# RT_audience_#reviews       461816.0
# RT_tomatometer_#reviews       195.0
# Name: Alien, dtype: object
# Progress: 98.23%
# Processing: https://www.rottentomatoes.com/m/apocalypse_now/
# Processing: https://www.rottentomatoes.com/m/apocalypse_now_1979/
# RT_audience_score               4.5
# RT_tomatometer_score           8.90
# RT_audience_#reviews       286824.0
# RT_tomatometer_#reviews        95.0
# Name: Apocalypse Now, dtype: object
# Progress: 98.27%
# Processing: https://www.rottentomatoes.com/m/mad_max/
# Processing: https://www.rottentomatoes.com/m/mad_max_1979/
# RT_audience_score               3.7
# RT_tomatometer_score           7.70
# RT_audience_#reviews       142497.0
# RT_tomatometer_#reviews        65.0
# Name: Mad Max, dtype: object
# Progress: 98.31%
# Processing: https://www.rottentomatoes.com/m/manhattan/
# Processing: https://www.rottentomatoes.com/m/manhattan_1979/
# RT_audience_score              4.3
# RT_tomatometer_score          8.50
# RT_audience_#reviews       51932.0
# RT_tomatometer_#reviews       70.0
# Name: Manhattan, dtype: object
# Progress: 98.35%
# Processing: https://www.rottentomatoes.com/m/the_warriors/
# Processing: https://www.rottentomatoes.com/m/the_warriors_1979/
# RT_audience_score              4.2
# RT_tomatometer_score          7.40
# RT_audience_#reviews       76381.0
# RT_tomatometer_#reviews       50.0
# Name: The Warriors, dtype: object
# Progress: 98.39%
# Processing: https://www.rottentomatoes.com/m/the_deer_hunter/
# Processing: https://www.rottentomatoes.com/m/the_deer_hunter_1979/
# RT_audience_score               4.3
# RT_tomatometer_score           8.60
# RT_audience_#reviews       103842.0
# RT_tomatometer_#reviews       132.0
# Name: The Deer Hunter, dtype: object
# Progress: 98.43%
# Processing: https://www.rottentomatoes.com/m/superman/
# Processing: https://www.rottentomatoes.com/m/superman_1978/
# RT_audience_score          N/A
# RT_tomatometer_score       N/A
# RT_audience_#reviews       2.0
# RT_tomatometer_#reviews    0.0
# Name: Superman, dtype: object
# Progress: 98.47%
# Processing: https://www.rottentomatoes.com/m/namehalloween____halloweenhalloween____halloweenhalloween____halloweenname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namehalloween____halloweenhalloween____halloweenhalloween____halloweenname_name_dtype_object_Name
# Halloween    2018
# Halloween    2007
# Halloween    1978
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Halloween    Halloween
# Halloween    Halloween
# Halloween    Halloween
# Name: Name, dtype: object
# Progress: 98.51%
# Processing: https://www.rottentomatoes.com/m/national_lampoons_animal_house/
# Processing: https://www.rottentomatoes.com/m/national_lampoons_animal_house_1978/
# RT_audience_score               4.3
# RT_tomatometer_score           7.70
# RT_audience_#reviews       185794.0
# RT_tomatometer_#reviews        54.0
# Name: National Lampoon's Animal House, dtype: object
# Progress: 98.55%
# Processing: https://www.rottentomatoes.com/m/grease/
# Processing: https://www.rottentomatoes.com/m/grease_1978/
# RT_audience_score                4.3
# RT_tomatometer_score            7.00
# RT_audience_#reviews       1161874.0
# RT_tomatometer_#reviews         77.0
# Name: Grease, dtype: object
# Progress: 98.59%
# Processing: https://www.rottentomatoes.com/m/jaws_2/
# Processing: https://www.rottentomatoes.com/m/jaws_2_1978/
# RT_audience_score               3.1
# RT_tomatometer_score           5.50
# RT_audience_#reviews       300070.0
# RT_tomatometer_#reviews        34.0
# Name: Jaws 2, dtype: object
# Progress: 98.63%
# Processing: https://www.rottentomatoes.com/m/midnight_express/
# Processing: https://www.rottentomatoes.com/m/midnight_express_1978/
# RT_audience_score              4.2
# RT_tomatometer_score          7.50
# RT_audience_#reviews       31216.0
# RT_tomatometer_#reviews       30.0
# Name: Midnight Express, dtype: object
# Progress: 98.67%
# Processing: https://www.rottentomatoes.com/m/saturday_night_fever/
# Processing: https://www.rottentomatoes.com/m/saturday_night_fever_1977/
# RT_audience_score               3.8
# RT_tomatometer_score           7.50
# RT_audience_#reviews       179548.0
# RT_tomatometer_#reviews        55.0
# Name: Saturday Night Fever, dtype: object
# Progress: 98.71%
# Processing: https://www.rottentomatoes.com/m/close_encounters_of_the_third_kind/
# Processing: https://www.rottentomatoes.com/m/close_encounters_of_the_third_kind_1977/
# RT_audience_score               4.1
# RT_tomatometer_score           9.00
# RT_audience_#reviews       142442.0
# RT_tomatometer_#reviews        70.0
# Name: Close Encounters of the Third Kind, dtype: object
# Progress: 98.75%
# Processing: https://www.rottentomatoes.com/m/the_spy_who_loved_me/
# Processing: https://www.rottentomatoes.com/m/the_spy_who_loved_me_1977/
# Could not scrape data for this movie: The Spy Who Loved Me
# Progress: 98.79%
# Processing: https://www.rottentomatoes.com/m/star_wars_episode_iv__a_new_hope/
# Processing: https://www.rottentomatoes.com/m/star_wars_episode_iv__a_new_hope_1977/
# Could not scrape data for this movie: Star Wars: Episode IV - A New Hope
# Progress: 98.83%
# Processing: https://www.rottentomatoes.com/m/eraserhead/
# Processing: https://www.rottentomatoes.com/m/eraserhead_1978/
# RT_audience_score              4.1
# RT_tomatometer_score          8.40
# RT_audience_#reviews       57784.0
# RT_tomatometer_#reviews       66.0
# Name: Eraserhead, dtype: object
# Progress: 98.87%
# Processing: https://www.rottentomatoes.com/m/namecarrie____carriecarrie____carriename_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namecarrie____carriecarrie____carriename_name_dtype_object_Name
# Carrie    2013
# Carrie    1976
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Carrie    Carrie
# Carrie    Carrie
# Name: Name, dtype: object
# Progress: 98.91%
# Processing: https://www.rottentomatoes.com/m/network/
# Processing: https://www.rottentomatoes.com/m/network_1976/
# RT_audience_score              4.4
# RT_tomatometer_score          8.50
# RT_audience_#reviews       36525.0
# RT_tomatometer_#reviews       75.0
# Name: Network, dtype: object
# Progress: 98.95%
# Processing: https://www.rottentomatoes.com/m/the_omen/
# Processing: https://www.rottentomatoes.com/m/the_omen_1976/
# Could not scrape data for this movie: The Omen
# Progress: 98.99%
# Processing: https://www.rottentomatoes.com/m/all_the_presidents_men/
# Processing: https://www.rottentomatoes.com/m/all_the_presidents_men_1976/
# RT_audience_score              4.3
# RT_tomatometer_score          9.10
# RT_audience_#reviews       50499.0
# RT_tomatometer_#reviews       71.0
# Name: All the President's Men, dtype: object
# Progress: 99.03%
# Processing: https://www.rottentomatoes.com/m/taxi_driver/
# Processing: https://www.rottentomatoes.com/m/taxi_driver_1976/
# RT_audience_score               4.4
# RT_tomatometer_score           9.10
# RT_audience_#reviews       261928.0
# RT_tomatometer_#reviews       159.0
# Name: Taxi Driver, dtype: object
# Progress: 99.07%
# Processing: https://www.rottentomatoes.com/m/barry_lyndon/
# Processing: https://www.rottentomatoes.com/m/barry_lyndon_1975/
# RT_audience_score              4.4
# RT_tomatometer_score          8.30
# RT_audience_#reviews       45304.0
# RT_tomatometer_#reviews       84.0
# Name: Barry Lyndon, dtype: object
# Progress: 99.11%
# Processing: https://www.rottentomatoes.com/m/one_flew_over_the_cuckoos_nest/
# Processing: https://www.rottentomatoes.com/m/one_flew_over_the_cuckoos_nest_1975/
# RT_audience_score               4.5
# RT_tomatometer_score           9.10
# RT_audience_#reviews       280360.0
# RT_tomatometer_#reviews       120.0
# Name: One Flew Over the Cuckoo's Nest, dtype: object
# Progress: 99.15%
# Processing: https://www.rottentomatoes.com/m/the_rocky_horror_picture_show/
# Processing: https://www.rottentomatoes.com/m/the_rocky_horror_picture_show_1975/
# RT_audience_score               4.2
# RT_tomatometer_score           6.90
# RT_audience_#reviews       366877.0
# RT_tomatometer_#reviews        48.0
# Name: The Rocky Horror Picture Show, dtype: object
# Progress: 99.19%
# Processing: https://www.rottentomatoes.com/m/jaws/
# Processing: https://www.rottentomatoes.com/m/jaws_1975/
# RT_audience_score               4.4
# RT_tomatometer_score           9.30
# RT_audience_#reviews       946639.0
# RT_tomatometer_#reviews       101.0
# Name: Jaws, dtype: object
# Progress: 99.23%
# Processing: https://www.rottentomatoes.com/m/monty_python_and_the_holy_grail/
# Processing: https://www.rottentomatoes.com/m/monty_python_and_the_holy_grail_1975/
# RT_audience_score               4.5
# RT_tomatometer_score           8.50
# RT_audience_#reviews       645215.0
# RT_tomatometer_#reviews        83.0
# Name: Monty Python and the Holy Grail, dtype: object
# Progress: 99.27%
# Processing: https://www.rottentomatoes.com/m/the_godfather_part_ii/
# Processing: https://www.rottentomatoes.com/m/the_godfather_part_ii_1974/
# Could not scrape data for this movie: The Godfather Part II
# Progress: 99.31%
# Processing: https://www.rottentomatoes.com/m/young_frankenstein/
# Processing: https://www.rottentomatoes.com/m/young_frankenstein_1974/
# RT_audience_score               4.4
# RT_tomatometer_score           8.60
# RT_audience_#reviews       209621.0
# RT_tomatometer_#reviews        72.0
# Name: Young Frankenstein, dtype: object
# Progress: 99.35%
# Processing: https://www.rottentomatoes.com/m/the_man_with_the_golden_gun/
# Processing: https://www.rottentomatoes.com/m/the_man_with_the_golden_gun_1974/
# Could not scrape data for this movie: The Man with the Golden Gun
# Progress: 99.4%
# Processing: https://www.rottentomatoes.com/m/the_texas_chain_saw_massacre/
# Processing: https://www.rottentomatoes.com/m/the_texas_chain_saw_massacre_1974/
# Could not scrape data for this movie: The Texas Chain Saw Massacre
# Progress: 99.44%
# Processing: https://www.rottentomatoes.com/m/chinatown/
# Processing: https://www.rottentomatoes.com/m/chinatown_1974/
# RT_audience_score              4.4
# RT_tomatometer_score          9.40
# RT_audience_#reviews       78341.0
# RT_tomatometer_#reviews       79.0
# Name: Chinatown, dtype: object
# Progress: 99.48%
# Processing: https://www.rottentomatoes.com/m/the_conversation/
# Processing: https://www.rottentomatoes.com/m/the_conversation_1974/
# RT_audience_score              4.2
# RT_tomatometer_score          8.90
# RT_audience_#reviews       35378.0
# RT_tomatometer_#reviews       71.0
# Name: The Conversation, dtype: object
# Progress: 99.52%
# Processing: https://www.rottentomatoes.com/m/blazing_saddles/
# Processing: https://www.rottentomatoes.com/m/blazing_saddles_1974/
# RT_audience_score               4.3
# RT_tomatometer_score           8.10
# RT_audience_#reviews       218751.0
# RT_tomatometer_#reviews        68.0
# Name: Blazing Saddles, dtype: object
# Progress: 99.56%
# Processing: https://www.rottentomatoes.com/m/the_exorcist/
# Processing: https://www.rottentomatoes.com/m/the_exorcist_1973/
# RT_audience_score               4.2
# RT_tomatometer_score           8.40
# RT_audience_#reviews       421443.0
# RT_tomatometer_#reviews       174.0
# Name: The Exorcist, dtype: object
# Progress: 99.6%
# Processing: https://www.rottentomatoes.com/m/the_sting/
# Processing: https://www.rottentomatoes.com/m/the_sting_1973/
# Could not scrape data for this movie: The Sting
# Progress: 99.64%
# Processing: https://www.rottentomatoes.com/m/namepapillon____papillonpapillon____papillonname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namepapillon____papillonpapillon____papillonname_name_dtype_object_Name
# Papillon    2018
# Papillon    1973
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Papillon    Papillon
# Papillon    Papillon
# Name: Name, dtype: object
# Progress: 99.68%
# Processing: https://www.rottentomatoes.com/m/serpico/
# Processing: https://www.rottentomatoes.com/m/serpico_1973/
# RT_audience_score              4.1
# RT_tomatometer_score          8.10
# RT_audience_#reviews       53902.0
# RT_tomatometer_#reviews       55.0
# Name: Serpico, dtype: object
# Progress: 99.72%
# Processing: https://www.rottentomatoes.com/m/the_wicker_man/
# Processing: https://www.rottentomatoes.com/m/the_wicker_man_1973/
# RT_audience_score                4
# RT_tomatometer_score          8.00
# RT_audience_#reviews       43491.0
# RT_tomatometer_#reviews       62.0
# Name: The Wicker Man, dtype: object
# Progress: 99.76%
# Processing: https://www.rottentomatoes.com/m/namerobin_hood____robin_hoodrobin_hood____robin_hoodname_name_dtype_object/
# Processing: https://www.rottentomatoes.com/m/namerobin_hood____robin_hoodrobin_hood____robin_hoodname_name_dtype_object_Name
# Robin Hood    2010
# Robin Hood    1973
# Name: year, dtype: int64/
# Could not scrape data for this movie: Name
# Robin Hood    Robin Hood
# Robin Hood    Robin Hood
# Name: Name, dtype: object
# Progress: 99.8%
# Processing: https://www.rottentomatoes.com/m/mean_streets/
# Processing: https://www.rottentomatoes.com/m/mean_streets_1974/
# RT_audience_score                4
# RT_tomatometer_score          8.80
# RT_audience_#reviews       55003.0
# RT_tomatometer_#reviews       75.0
# Name: Mean Streets, dtype: object
# Progress: 99.84%
# Processing: https://www.rottentomatoes.com/m/american_graffiti/
# Processing: https://www.rottentomatoes.com/m/american_graffiti_1973/
# RT_audience_score                4
# RT_tomatometer_score          8.60
# RT_audience_#reviews       64846.0
# RT_tomatometer_#reviews       62.0
# Name: American Graffiti, dtype: object
# Progress: 99.88%
# Processing: https://www.rottentomatoes.com/m/live_and_let_die/
# Processing: https://www.rottentomatoes.com/m/live_and_let_die_1973/
# RT_audience_score              3.6
# RT_tomatometer_score          5.80
# RT_audience_#reviews       65030.0
# RT_tomatometer_#reviews       53.0
# Name: Live and Let Die, dtype: object
# Progress: 99.92%
# Processing: https://www.rottentomatoes.com/m/deliverance/
# Processing: https://www.rottentomatoes.com/m/deliverance_1972/
# RT_audience_score              3.9
# RT_tomatometer_score          8.40
# RT_audience_#reviews       49561.0
# RT_tomatometer_#reviews       66.0
# Name: Deliverance, dtype: object
# Progress: 99.96%
# Processing: https://www.rottentomatoes.com/m/the_godfather/
# Processing: https://www.rottentomatoes.com/m/the_godfather_1972/
# RT_audience_score               4.8
# RT_tomatometer_score           9.40
# RT_audience_#reviews       735939.0
# RT_tomatometer_#reviews       151.0
# Name: The Godfather, dtype: object
# Progress: 100.0%

# %%
len(df_movie[df_movie['RT_tomatometer_score'].isnull()])
# Out:
# 362

# %%
362/2480
# Out:
# 0.14596774193548387

# %%
df_movie.columns
# Out:
# Index(['IMDB Ratings', 'IMDB Score', 'Content Rating', 'Date Released', 'year',
#        'month', 'day of the week', 'Genres', 'Genre A', 'Genre B', 'Genre C',
#        'Keywords', 'Keyword 1', 'Keyword 2', 'Keyword 3', 'Stars', 'Star 1',
#        'Star 2', 'Star 3', 'Directors', 'Director 1', 'Director 2',
#        'Director 3', 'Writers', 'Writer 1', 'Writer 2', 'Writer 3', 'Runtime',
#        'Nominations', 'Awards', 'Estimated Budget', 'Budget Currency',
#        'Gross Revenue US&Canada USD', 'Opening Weekend Revenue US&Canada USD',
#        'Gross Revenue Worldwide USD', 'Name',
#        'rottentomatoes_tomatometer_score', 'rottentomatoes_audience_#reviews',
#        'rottentomatoes_tomatometer_#reviews', 'RT_audience_score',
#        'RT_tomatometer_score', 'RT_audience_#reviews',
#        'RT_tomatometer_#reviews'],
#       dtype='object')

# %%
#Start Here if csv export is complete

df_movie = pd.read_csv('movie_data_with_rt3.csv')
df_movie.index = df_movie['Name']

#Convert audience score from 5 star scale to out of 10 score
#df_movie['RT_audience_score'] = df_movie['RT_audience_score']*2

#Remove rows where RT_audience score is missing by first changing N/A to null
df_movie['RT_audience_score'].replace('N/A', np.nan, inplace=True)

# Drop rows where 'RT_audience_score' is null
df_movie.dropna(subset=['RT_audience_score'], inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Count missing values in each column
missing_values = df_movie.isnull().sum()

# Display the count of missing values for each column
print(missing_values)
# Out:
# IMDB Ratings                              0
# IMDB Score                                0
# Content Rating                            0
# Date Released                             0
# year                                      0
# month                                     0
# day of the week                           0
# Genres                                    0
# Genre A                                   0
# Genre B                                   0
# Genre C                                   0
# Keywords                                  0
# Keyword 1                                 0
# Keyword 2                                 0
# Keyword 3                                 0
# Stars                                     0
# Star 1                                    0
# Star 2                                    0
# Star 3                                    0
# Directors                                 0
# Director 1                                0
# Director 2                                0
# Director 3                                0
# Writers                                   0
# Writer 1                                  0
# Writer 2                                  0
# Writer 3                                  0
# Runtime                                   0
# Nominations                               0
# Awards                                    0
# Estimated Budget                          0
# Budget Currency                           0
# Gross Revenue US&Canada USD               0
# Opening Weekend Revenue US&Canada USD     0
# Gross Revenue Worldwide USD               0
# Name                                      0
# RT_audience_score                         0
# RT_tomatometer_score                     36
# RT_audience_#reviews                      0
# RT_tomatometer_#reviews                   0
# dtype: int64

# %%
# Assuming df contains IMDb and RT scores in columns 'IMDB Score' and 'RT_audience_score'
plt.figure(figsize=(8, 6))

# Plot IMDb scores
plt.hist(df_movie['IMDB Score'], bins=20, alpha=0.7, label='IMDb Score', color='blue')

# Plot RT scores
plt.hist(df_movie['RT_audience_score'], bins=20, alpha=0.7, label='RT Score', color='green')

plt.title('IMDb vs RT Audience Scores')
plt.xlabel('Scores')
plt.ylabel('Frequency')
plt.legend()
plt.show()
